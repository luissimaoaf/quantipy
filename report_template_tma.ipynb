# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf
import warnings

from quantipy.assets import Currency, Equity
from quantipy.trading import Broker, Strategy, TripleMovingAverage
from quantipy.backtest import Backtester
import quantipy.utils as _utils

# %matplotlib inline
warnings.filterwarnings('ignore')

# backtest period
BACKTEST_START = '2016-01-01'
LIVE_START = '2019-01-01'

# trading universe
CAPITAL = 10_000
usd = Currency('USD')
spy = Equity('SPY', 'SPY')
ndq = Equity('NASDAQ', '^IXIC')
MKT = [spy, ndq]
BENCHMARK = 'SPY'

# strategy
STRATEGY = TripleMovingAverage([spy], {})

# strategy parameters

PARAMS = {
    'history1': [3, 4, 5, 6], 
    'history2': [7, 9, 10, 12, 15],
    'history3': [21, 24, 27, 30]
}

# PARAMS = {
#     'history1': [4], 
#     'history2': [15],
#     'history3': [30]
# }

# optimization metric defined as a function of the equity curve
def METRIC(equity):
    returns = _utils.compute_returns(equity)
    return _utils.sortino(returns)

# %%
# getting data
data = {}
for asset in MKT:
    ticker = yf.ticker.Ticker(asset.symbol)
    ticker_data = ticker.history(start=BACKTEST_START, end=LIVE_START,
                                 interval='1d')
    data[asset.symbol] = ticker_data

broker = Broker(data=data, initial_capital=CAPITAL, currency=usd)
backtester = Backtester(data)

opt_results = backtester.optimize(
    STRATEGY, broker, PARAMS, metric=METRIC, save_logs=False, benchmark=BENCHMARK
)

print(f"Optimal parameters: {opt_results['best_params']}")
# Out:
# Preparing optimization...
# Starting optimization...
# {'history1': 3, 'history2': 7, 'history3': 21}
# Score: -0.5422583470038661
# {'history1': 3, 'history2': 7, 'history3': 24}
# Score: -0.5433760183575577
# {'history1': 3, 'history2': 7, 'history3': 27}
# Score: -0.5445006293434042
# {'history1': 3, 'history2': 7, 'history3': 30}
# Score: -0.5463663494211896
# {'history1': 3, 'history2': 9, 'history3': 21}
# Score: -0.4141802932828313
# {'history1': 3, 'history2': 9, 'history3': 24}
# Score: -0.2380277595091392
# {'history1': 3, 'history2': 9, 'history3': 27}
# Score: -0.238520399272833
# {'history1': 3, 'history2': 9, 'history3': 30}
# Score: -0.18233009558629604
# {'history1': 3, 'history2': 10, 'history3': 21}
# Score: -0.21039557123474634
# {'history1': 3, 'history2': 10, 'history3': 24}
# Score: -0.019427910155134995
# {'history1': 3, 'history2': 10, 'history3': 27}
# Score: -0.019468119587377954
# {'history1': 3, 'history2': 10, 'history3': 30}
# Score: 0.04759883313238339
# {'history1': 3, 'history2': 12, 'history3': 21}
# Score: -0.4174688087026641
# {'history1': 3, 'history2': 12, 'history3': 24}
# Score: -0.1443706791169088
# {'history1': 3, 'history2': 12, 'history3': 27}
# Score: -0.1446694792963126
# {'history1': 3, 'history2': 12, 'history3': 30}
# Score: -0.08770842712839173
# {'history1': 3, 'history2': 15, 'history3': 21}
# Score: -0.3872131323645153
# {'history1': 3, 'history2': 15, 'history3': 24}
# Score: -0.11548003794968008
# {'history1': 3, 'history2': 15, 'history3': 27}
# Score: -0.11571904393252924
# {'history1': 3, 'history2': 15, 'history3': 30}
# Score: -0.05243697208905425
# {'history1': 4, 'history2': 7, 'history3': 21}
# Score: -1.0390328817090517
# {'history1': 4, 'history2': 7, 'history3': 24}
# Score: -0.8872077819486394
# {'history1': 4, 'history2': 7, 'history3': 27}
# Score: -0.8890440124494334
# {'history1': 4, 'history2': 7, 'history3': 30}
# Score: -0.8282570969486575
# {'history1': 4, 'history2': 9, 'history3': 21}
# Score: -0.795569623486268
# {'history1': 4, 'history2': 9, 'history3': 24}
# Score: -0.6166007564303702
# {'history1': 4, 'history2': 9, 'history3': 27}
# Score: -0.6178769187215566
# {'history1': 4, 'history2': 9, 'history3': 30}
# Score: -0.5725659577847604
# {'history1': 4, 'history2': 10, 'history3': 21}
# Score: -0.50951673983711
# {'history1': 4, 'history2': 10, 'history3': 24}
# Score: -0.3220041104244481
# {'history1': 4, 'history2': 10, 'history3': 27}
# Score: -0.32267055382245774
# {'history1': 4, 'history2': 10, 'history3': 30}
# Score: -0.2649395717016492
# {'history1': 4, 'history2': 12, 'history3': 21}
# Score: -0.27813887483361777
# {'history1': 4, 'history2': 12, 'history3': 24}
# Score: -0.0024852681276248266
# {'history1': 4, 'history2': 12, 'history3': 27}
# Score: -0.0024904118213924715
# {'history1': 4, 'history2': 12, 'history3': 30}
# Score: -0.0024955875851520085
# {'history1': 4, 'history2': 15, 'history3': 21}
# Score: 0.1019965349096582
# {'history1': 4, 'history2': 15, 'history3': 24}
# Score: 0.3940375851358534
# {'history1': 4, 'history2': 15, 'history3': 27}
# Score: 0.39485311431290426
# {'history1': 4, 'history2': 15, 'history3': 30}
# Score: 0.3956737281655429
# {'history1': 5, 'history2': 7, 'history3': 21}
# Score: -1.432307657254315
# {'history1': 5, 'history2': 7, 'history3': 24}
# Score: -1.2849669297980837
# {'history1': 5, 'history2': 7, 'history3': 27}
# Score: -1.28762639189593
# {'history1': 5, 'history2': 7, 'history3': 30}
# Score: -1.238746943465331
# {'history1': 5, 'history2': 9, 'history3': 21}
# Score: -0.7477509005445065
# {'history1': 5, 'history2': 9, 'history3': 24}
# Score: -0.517562391763164
# {'history1': 5, 'history2': 9, 'history3': 27}
# Score: -0.5186335769682034
# {'history1': 5, 'history2': 9, 'history3': 30}
# Score: -0.519711440817509
# {'history1': 5, 'history2': 10, 'history3': 21}
# Score: -0.3869300523705781
# {'history1': 5, 'history2': 10, 'history3': 24}
# Score: -0.12816095843855185
# {'history1': 5, 'history2': 10, 'history3': 27}
# Score: -0.12842620978742877
# {'history1': 5, 'history2': 10, 'history3': 30}
# Score: -0.1286931149300583
# {'history1': 5, 'history2': 12, 'history3': 21}
# Score: -0.10078099186028347
# {'history1': 5, 'history2': 12, 'history3': 24}
# Score: 0.18370560879478806
# {'history1': 5, 'history2': 12, 'history3': 27}
# Score: 0.18408581943867458
# {'history1': 5, 'history2': 12, 'history3': 30}
# Score: 0.18446840062653883
# {'history1': 5, 'history2': 15, 'history3': 21}
# Score: 0.06435059301821452
# {'history1': 5, 'history2': 15, 'history3': 24}
# Score: 0.371613583655289
# {'history1': 5, 'history2': 15, 'history3': 27}
# Score: 0.372382702469056
# {'history1': 5, 'history2': 15, 'history3': 30}
# Score: 0.37315661659826543
# {'history1': 6, 'history2': 7, 'history3': 21}
# Score: -0.9026645640617672
# {'history1': 6, 'history2': 7, 'history3': 24}
# Score: -0.6902437743517394
# {'history1': 6, 'history2': 7, 'history3': 27}
# Score: -0.6916723536510148
# {'history1': 6, 'history2': 7, 'history3': 30}
# Score: -0.6437739450552189
# {'history1': 6, 'history2': 9, 'history3': 21}
# Score: -0.6853557213748681
# {'history1': 6, 'history2': 9, 'history3': 24}
# Score: -0.44268385559931717
# {'history1': 6, 'history2': 9, 'history3': 27}
# Score: -0.4436000666768116
# {'history1': 6, 'history2': 9, 'history3': 30}
# Score: -0.4445219901631688
# {'history1': 6, 'history2': 10, 'history3': 21}
# Score: -0.5619260132066783
# {'history1': 6, 'history2': 10, 'history3': 24}
# Score: -0.30792857812176777
# {'history1': 6, 'history2': 10, 'history3': 27}
# Score: -0.30856588976253296
# {'history1': 6, 'history2': 10, 'history3': 30}
# Score: -0.30920717492507116
# {'history1': 6, 'history2': 12, 'history3': 21}
# Score: -0.06679544733805465
# {'history1': 6, 'history2': 12, 'history3': 24}
# Score: 0.12116650902033255
# {'history1': 6, 'history2': 12, 'history3': 27}
# Score: 0.12141728414208487
# {'history1': 6, 'history2': 12, 'history3': 30}
# Score: 0.1216696228009559
# {'history1': 6, 'history2': 15, 'history3': 21}
# Score: -0.27040249833248015
# {'history1': 6, 'history2': 15, 'history3': 24}
# Score: -0.1022523095764339
# {'history1': 6, 'history2': 15, 'history3': 27}
# Score: -0.10246393847942703
# {'history1': 6, 'history2': 15, 'history3': 30}
# Score: -0.10267688685000914
# Optimal parameters: {'history1': 4, 'history2': 15, 'history3': 30}

# %%
backtester.show_report()
# Out:
# Backtest Results
# ----------------------------------------
# Metric           Strategy      Benchmark
# ----------------------------------------
# Total Return:       5.64%         31.92%
# Avg gain (day):     0.40%          0.51%
# Avg loss (day):    -0.40%         -0.52%
# Beta (BM):         0.3757              1
# Sharpe Ratio:      0.2885         0.9572
# Sortino Ratio:     0.3957         1.3215
# ----------------------------------------
# Max Drawdown:     -11.26%        -19.35%
# Avg Drawdown:      -4.38%         -2.16%
# Avg DD Bars:           32              8
# Longest DD:           426            131
# ----------------------------------------
# Time in Market:    71.92%           100%
# Trades:                29
# Best Win:           7.27%
# Avg Win:            2.55%
# Worst Loss:        -3.36%
# Avg Loss:          -1.42%
# Win/Loss ratio:      0.71
# Win %:             41.38%

# %%
# getting data
data = {}
for asset in MKT:
    ticker = yf.ticker.Ticker(asset.symbol)
    ticker_data = ticker.history(start=LIVE_START, interval='1d')
    data[asset.symbol] = ticker_data

# trading on 2x leverage
broker = Broker(data=data, initial_capital=CAPITAL, currency=usd, margin=0.5)
live_backtester = Backtester(data)

live_backtest = live_backtester.run(STRATEGY, broker, save_logs=True)

# %%
results = live_backtester.process_results(benchmark=BENCHMARK)
live_backtester.show_report()
# Out:
# Backtest Results
# ----------------------------------------
# Metric           Strategy      Benchmark
# ----------------------------------------
# Total Return:     213.04%        142.61%
# Avg gain (day):     1.24%          0.83%
# Avg loss (day):    -1.24%         -0.86%
# Beta (BM):         0.6887              1
# Sharpe Ratio:      1.0201         0.8278
# Sortino Ratio:     1.4955         1.1578
# ----------------------------------------
# Max Drawdown:     -27.71%        -33.72%
# Avg Drawdown:      -7.96%         -5.75%
# Avg DD Bars:           19             11
# Longest DD:           555            488
# ----------------------------------------
# Time in Market:    70.52%           100%
# Trades:                45
# Best Win:           9.55%
# Avg Win:            3.90%
# Worst Loss:        -7.11%
# Avg Loss:          -2.27%
# Win/Loss ratio:      1.50
# Win %:             60.00%
